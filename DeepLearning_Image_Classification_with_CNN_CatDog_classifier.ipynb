# %% [markdown]
# ![Hilmi Katirci Data Analyst.png](data:image/png;base64,...)

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Image Classification with CNN<br><br>Cat-Dog Classification Project<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# The Dogs vs. Cats dataset is a common computer vision dataset in which pictures are classified as either including a dog or a cat.
#
# After the dataset is well studied, it can be used to understand and practice how to design, evaluate, and apply convolutional neural networks for image classification.
#
# You will build a classifier with images and try to detect dogs versus cats using CNN.
#
# Train set includes 12500 cat-5026 dog images, validation set includes 1219 cat-1071 dog images and test set incgludes 6897 cat and dogs images together.

# %% [markdown]
# # Import Libraries and Export Images from Zip_File

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
import tensorflow as tf

tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Unzip the file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/cat_dog_data.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# # Recognizing and Understanding Data

# %%
my_data_dir = 'data'

# %%
os.listdir(my_data_dir)
# Out:
# ['test', 'validation', 'train']

# %%
val_path = os.path.join(my_data_dir, 'validation')
train_path = os.path.join(my_data_dir, 'train')
test_path = os.path.join(my_data_dir, 'test')

# %%
os.listdir(train_path)
# Out:
# ['cat', 'dog']

# %%
os.listdir(val_path)
# Out:
# ['cat', 'dog']

# %%
os.listdir(test_path)[:5]
# Out:
# ['10148.jpg', '10560.jpg', '4980.jpg', '5172.jpg', '5660.jpg']

# %%
# Alternative method
import pathlib

data_dir = pathlib.Path(train_path)  # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
# created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['cat' 'dog']

# %% [markdown]
# **Let's check how many images there are.**

# %%
len(os.listdir(os.path.join(train_path, 'cat'))), len(os.listdir(os.path.join(train_path, 'dog')))
# Out:
# (12500, 5026)

# %%
len(os.listdir(os.path.join(val_path, 'cat'))), len(os.listdir(os.path.join(val_path, 'dog')))
# Out:
# (1219, 1071)

# %%
# Walk through cell_images directory and list number of files
for dirpath, dirnames, filenames in os.walk(my_data_dir):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'data'.
# There are 0 directories and 6897 images in 'data/test'.
# There are 2 directories and 0 images in 'data/validation'.
# There are 0 directories and 1219 images in 'data/validation/cat'.
# There are 0 directories and 1071 images in 'data/validation/dog'.
# There are 2 directories and 0 images in 'data/train'.
# There are 0 directories and 12500 images in 'data/train/cat'.
# There are 0 directories and 5026 images in 'data/train/dog'.

# %% [markdown]
# **Let's take an example images from both train-cat and train-dog folders to observe process**

# %%
os.listdir(os.path.join(train_path, 'cat'))[0]
# Out:
# 'cat.4470.jpg'

# %%
os.listdir(os.path.join(train_path, 'dog'))[0]
# Out:
# 'dog.1404.jpg'

# %%
path1 = os.path.join(train_path, 'cat', os.listdir(os.path.join(train_path, 'cat'))[0])
path2 = os.path.join(train_path, 'dog', os.listdir(os.path.join(train_path, 'dog'))[0])

# %%
cat_img = imread(path1)
dog_img = imread(path2)

# %%
plt.imshow(cat_img)
plt.show()

# %%
plt.imshow(dog_img)
plt.show()

# %%
# View an image
import random


def view_random_image(target_dir, target_class):
    """Display and return an image given the target_dir and target_class.
    Args:
        target_dir (str): The full or relative path of the directory of the target.
        target_class (str): The name of the target_class you want to display and return.
    Returns:
        img: (np.ndarray): Image as numpy array.
    """
    # Setup target directory (we'll view images from here)
    target_folder = os.path.join(target_dir, target_class)

    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)

    # Read in the image and plot it using matplotlib
    img = imread(os.path.join(target_folder, random_image[0]))
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off");

    print(f"Image shape: {img.shape}")  # show the shape of the image

    return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_path,
                        target_class="cat")
# Out:
# Image shape: (374, 500, 3)

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=val_path,
                        target_class="dog")
# Out:
# Image shape: (377, 500, 3)

# %%
# View a random image from the training dataset
import random
img = view_random_image(target_dir=train_path,
                        target_class=random.choice(class_names))
                        # get a random class name
# Out:
# Image shape: (374, 500, 3)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Defining Input Shape

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
cat_img.shape
# Out:
# (345, 357, 3)

# %%
dog_img.shape
# Out:
# (300, 226, 3)

# %% [markdown]
# ```python
# x = []
# y = []
# for image in os.listdir(os.path.join(train_path, 'cat')):
#
#     img = imread(os.path.join(train_path, 'cat', image)
#     d1,d2,_ = img.shape
#     x.append(d1)
#     y.append(d2)
# ```

# %%
x = [imread(os.path.join(train_path, 'cat', image)).shape[0]
     for image
     in os.listdir(os.path.join(train_path, 'cat'))]
y = [imread(os.path.join(train_path, 'cat', image)).shape[1]
     for image
     in os.listdir(os.path.join(train_path, 'cat'))]

# %%
sns.scatterplot(x=x, y=y)
plt.show()

# %%
np.mean(x), np.median(x)
# Out:
# (356.46712, 374.0)

# %%
np.mean(y), np.median(y)
# Out:
# (410.52264, 470.0)

# %%
image_shape = (128, 128, 3)

# %% [markdown]
# ## Scaling

# %% [markdown]
# **Let's check the images if they are needed to be scaled or not**

# %%
cat_img.max()
# Out:
# 255

# %%
cat_img.min()
# Out:
# 0

# %%
dog_img.max(), dog_img.min()
# Out:
# (255, 0)

# %% [markdown]
# As we see above, images need to be scaled

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.
#
# Data augmentation is a way to try and prevent a model overfitting. If your model is overfiting (e.g. the validation loss keeps increasing), you may want to try using data augmentation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# help(ImageDataGenerator)

# %%
image_gen = ImageDataGenerator(
    rotation_range=15,  # rotate the image 15 degrees
    width_shift_range=0.10,  # Shift the pic width by a max of 10%
    height_shift_range=0.10,  # Shift the pic height by a max of 10%
    rescale=1/255,  # Rescale the image by normalzing it.
    shear_range=0.1,  # Shear means cutting away part of the image (max 10%)
    zoom_range=0.1,  # Zoom in by 10% max
    horizontal_flip=True,  # Allow horizontal flipping
    fill_mode='nearest'  # Fill in missing pixels with the nearest filled value
    )

# %%
val_image_gen = ImageDataGenerator(rescale=1/255)

# %%
plt.imshow(dog_img)
plt.show()

# %%
plt.imshow(image_gen.random_transform(dog_img))
plt.show()

# %% [markdown]
# ### Taking the path to a directory & Generating batches of augmented data
#
# flow_from_directory function works with images organized in sub-directories. Your directories should include only one class of images, so one folder per class of images.

# %%
# help(image_gen.flow_from_directory)
# Takes the path to a directory & generates batches of augmented data.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
val_image_gen.flow_from_directory(val_path)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 0 images belonging to 0 classes.

# %%
batch_size = 32

# %%
image_shape
# Out:
# (128, 128, 3)

# %%
train_image_gen = image_gen.flow_from_directory(directory=train_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='binary',
                                                shuffle=True)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
val_image_gen = val_image_gen.flow_from_directory(directory=val_path,
                                                  target_size=image_shape[:2],
                                                  color_mode='rgb',
                                                  batch_size=batch_size,
                                                  class_mode='binary',
                                                  shuffle=False)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
train_image_gen[0][0].shape
# Out:
# (32, 128, 128, 3)

# %%
len(train_image_gen), len(val_image_gen)
# Out:
# (548, 72)

# %%
len(train_image_gen)*batch_size, len(val_image_gen)*batch_size
# Out:
# (17536, 2304)

# %%
# Get a sample of the training data batch
images, labels = train_image_gen.next()  # get the 'next' batch of images/labels
images.shape, labels.shape
# Out:
# ((32, 128, 128, 3), (32,))

# %%
# Get a sample of the testing data batch
images, labels = val_image_gen.next()  # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %% [markdown]
# # Modelling-1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
model1 = Sequential()

model1.add(Conv2D(filters=16,
                  kernel_size=(3, 3),
                  input_shape=image_shape,
                  activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=32,
                  kernel_size=(3, 3),
                  activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=64,
                  kernel_size=(3, 3),
                  activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=128,
                  kernel_size=(3, 3),
                  activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())

model1.add(Dense(128))
model1.add(Activation('relu'))

model1.add(Dense(64))
model1.add(Activation('relu'))

model1.add(Dense(1))
model1.add(Activation('sigmoid'))

model1.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  activation (Activation)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 695,713
# Trainable params: 695,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss',mode="min",
                           patience=4,
                           restore_best_weights=True)

# %%
model1.fit(train_image_gen,
           epochs=15,
           steps_per_epoch=len(train_image_gen),
           validation_data=val_image_gen,
           validation_steps=len(val_image_gen),
           callbacks=[early_stop])
# Out:
# Epoch 1/15
# 548/548 [==============================] - 108s 198ms/step - loss: 0.2632 - accuracy: 0.8886 - val_loss: 0.3148 - val_accuracy: 0.8721
# Epoch 2/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2558 - accuracy: 0.8916 - val_loss: 0.3256 - val_accuracy: 0.8672
# Epoch 3/15
# 548/548 [==============================] - 109s 198ms/step - loss: 0.2459 - accuracy: 0.8967 - val_loss: 0.2930 - val_accuracy: 0.8742
# Epoch 4/15
# 548/548 [==============================] - 114s 208ms/step - loss: 0.2362 - accuracy: 0.8986 - val_loss: 0.3196 - val_accuracy: 0.8672
# Epoch 5/15
# 548/548 [==============================] - 109s 199ms/step - loss: 0.2308 - accuracy: 0.9037 - val_loss: 0.2779 - val_accuracy: 0.8926
# Epoch 6/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2224 - accuracy: 0.9060 - val_loss: 0.2591 - val_accuracy: 0.8921
# Epoch 7/15
# 548/548 [==============================] - 108s 198ms/step - loss: 0.2136 - accuracy: 0.9112 - val_loss: 0.2781 - val_accuracy: 0.8891
# Epoch 8/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2089 - accuracy: 0.9123 - val_loss: 0.2925 - val_accuracy: 0.8948
# Epoch 9/15
# 548/548 [==============================] - 109s 199ms/step - loss: 0.2053 - accuracy: 0.9154 - val_loss: 0.2827 - val_accuracy: 0.8895
# Epoch 10/15
# 548/548 [==============================] - 111s 203ms/step - loss: 0.1947 - accuracy: 0.9193 - val_loss: 0.2603 - val_accuracy: 0.8983

# %%
summary = pd.DataFrame(model1.history.history)

# %%
summary[["loss", "val_loss"]].plot()
plt.show()

# %%
summary[["accuracy", "val_accuracy"]].plot()
plt.show()

# %% [markdown]
# # Modelling-2

# %%
model2 = Sequential()

model2.add(Conv2D(filters=16,
                  kernel_size=(3, 3),
                  input_shape=image_shape,
                  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=32,
                  kernel_size=(3, 3),
                  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=64,
                  kernel_size=(3, 3),
                  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=128,
                  kernel_size=(3, 3),
                  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Flatten())

model2.add(Dense(128))
model2.add(Activation('relu'))

model2.add(Dense(128))
model2.add(Activation('relu'))

model2.add(Dense(1))
model2.add(Activation('sigmoid'))

model2.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 16)      448
#
#  batch_normalization (BatchN  (None, 126, 126, 16)     64
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 61, 61, 32)       128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_3 (Dense)             (None, 128)               589952
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 704,993
# Trainable params: 704,513
# Non-trainable params: 480
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss',mode="min",
                           patience=4,
                           restore_best_weights=True)

# %%
model2.fit(train_image_gen,
           epochs=15,
           steps_per_epoch=len(train_image_gen),
           validation_data=val_image_gen,
           validation_steps=len(val_image_gen),
           callbacks=[early_stop])
# Out:
# Epoch 1/15
# 548/548 [==============================] - 110s 200ms/step - loss: 0.5120 - accuracy: 0.7627 - val_loss: 0.7156 - val_accuracy: 0.6079
# Epoch 2/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.4237 - accuracy: 0.8074 - val_loss: 0.4850 - val_accuracy: 0.7773
# Epoch 3/15
# 548/548 [==============================] - 109s 199ms/step - loss: 0.3623 - accuracy: 0.8390 - val_loss: 0.7991 - val_accuracy: 0.6930
# Epoch 4/15
# 548/548 [==============================] - 113s 207ms/step - loss: 0.3206 - accuracy: 0.8615 - val_loss: 0.5531 - val_accuracy: 0.7646
# Epoch 5/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2873 - accuracy: 0.8779 - val_loss: 0.4960 - val_accuracy: 0.7773
# Epoch 6/15
# 548/548 [==============================] - 108s 196ms/step - loss: 0.2531 - accuracy: 0.8916 - val_loss: 0.4533 - val_accuracy: 0.8166
# Epoch 7/15
# 548/548 [==============================] - 109s 199ms/step - loss: 0.2437 - accuracy: 0.8982 - val_loss: 0.3183 - val_accuracy: 0.8672
# Epoch 8/15
# 548/548 [==============================] - 111s 203ms/step - loss: 0.2288 - accuracy: 0.9025 - val_loss: 0.3065 - val_accuracy: 0.8760
# Epoch 9/15
# 548/548 [==============================] - 108s 198ms/step - loss: 0.2156 - accuracy: 0.9109 - val_loss: 0.3338 - val_accuracy: 0.8629
# Epoch 10/15
# 548/548 [==============================] - 111s 203ms/step - loss: 0.2078 - accuracy: 0.9129 - val_loss: 0.3101 - val_accuracy: 0.8843
# Epoch 11/15
# 548/548 [==============================] - 107s 196ms/step - loss: 0.1947 - accuracy: 0.9179 - val_loss: 0.2906 - val_accuracy: 0.8799
# Epoch 12/15
# 548/548 [==============================] - 107s 195ms/step - loss: 0.1899 - accuracy: 0.9201 - val_loss: 0.2694 - val_accuracy: 0.9022
# Epoch 13/15
# 548/548 [==============================] - 111s 202ms/step - loss: 0.1821 - accuracy: 0.9259 - val_loss: 0.2799 - val_accuracy: 0.8869
# Epoch 14/15
# 548/548 [==============================] - 109s 199ms/step - loss: 0.1740 - accuracy: 0.9267 - val_loss: 0.3706 - val_accuracy: 0.8563
# Epoch 15/15
# 548/548 [==============================] - 108s 196ms/step - loss: 0.1733 - accuracy: 0.9291 - val_loss: 0.2755 - val_accuracy: 0.8917

# %%
summary = pd.DataFrame(model2.history.history)

# %%
summary[["loss", "val_loss"]].plot()
plt.show()

# %%
summary[["accuracy", "val_accuracy"]].plot()
plt.show()

# %% [markdown]
# # Modelling-3

# %%
model3 = Sequential()

model3.add(Conv2D(filters=16,
                  kernel_size=(3, 3),
                  padding='same',
                  input_shape=image_shape,
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=16,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=32,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=32,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=64,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=64,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=128,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=128,
                  kernel_size=(3, 3),
                  padding='same',
                  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Flatten())

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(1))
model3.add(Activation('sigmoid'))

model3.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 128, 128, 16)      448
#
#  batch_normalization_4 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 16)      2320
#
#  batch_normalization_5 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 32)        4640
#
#  batch_normalization_6 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 32)        9248
#
#  batch_normalization_7 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 64)        18496
#
#  batch_normalization_8 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_9 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_11 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 128)               1048704
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  activation_7 (Activation)   (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,360,785
# Trainable params: 1,359,825
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss',mode="min",
                           patience=4,
                           restore_best_weights=True)

# %%
model3.fit(
    train_image_gen,
    epochs=20,
    steps_per_epoch=len(train_image_gen),
    validation_data=val_image_gen,
    validation_steps=len(val_image_gen),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 548/548 [==============================] - 118s 212ms/step - loss: 0.5674 - accuracy: 0.7351 - val_loss: 0.7597 - val_accuracy: 0.6585
# Epoch 2/20
# 548/548 [==============================] - 113s 206ms/step - loss: 0.4635 - accuracy: 0.7856 - val_loss: 0.6133 - val_accuracy: 0.7332
# Epoch 3/20
# 548/548 [==============================] - 113s 207ms/step - loss: 0.4056 - accuracy: 0.8183 - val_loss: 0.4480 - val_accuracy: 0.7908
# Epoch 4/20
# 548/548 [==============================] - 117s 213ms/step - loss: 0.3491 - accuracy: 0.8468 - val_loss: 0.4839 - val_accuracy: 0.7856
# Epoch 5/20
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2977 - accuracy: 0.8729 - val_loss: 0.3924 - val_accuracy: 0.8314
# Epoch 6/20
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2508 - accuracy: 0.8952 - val_loss: 0.3565 - val_accuracy: 0.8507
# Epoch 7/20
# 548/548 [==============================] - 115s 209ms/step - loss: 0.2216 - accuracy: 0.9094 - val_loss: 0.3137 - val_accuracy: 0.8616
# Epoch 8/20
# 548/548 [==============================] - 111s 203ms/step - loss: 0.2009 - accuracy: 0.9177 - val_loss: 0.5683 - val_accuracy: 0.7834
# Epoch 9/20
# 548/548 [==============================] - 111s 203ms/step - loss: 0.1871 - accuracy: 0.9233 - val_loss: 0.2658 - val_accuracy: 0.8983
# Epoch 10/20
# 548/548 [==============================] - 114s 207ms/step - loss: 0.1714 - accuracy: 0.9308 - val_loss: 0.2681 - val_accuracy: 0.9048
# Epoch 11/20
# 548/548 [==============================] - 111s 202ms/step - loss: 0.1603 - accuracy: 0.9333 - val_loss: 0.2622 - val_accuracy: 0.9026
# Epoch 12/20
# 548/548 [==============================] - 116s 212ms/step - loss: 0.1532 - accuracy: 0.9397 - val_loss: 0.3194 - val_accuracy: 0.8707
# Epoch 13/20
# 548/548 [==============================] - 112s 205ms/step - loss: 0.1413 - accuracy: 0.9427 - val_loss: 0.2609 - val_accuracy: 0.9057
# Epoch 14/20
# 548/548 [==============================] - 112s 205ms/step - loss: 0.1390 - accuracy: 0.9445 - val_loss: 0.2516 - val_accuracy: 0.9066
# Epoch 15/20
# 548/548 [==============================] - 114s 207ms/step - loss: 0.1343 - accuracy: 0.9459 - val_loss: 0.2726 - val_accuracy: 0.9127
# Epoch 16/20
# 548/548 [==============================] - 112s 204ms/step - loss: 0.1232 - accuracy: 0.9504 - val_loss: 0.3045 - val_accuracy: 0.8952
# Epoch 17/20
# 548/548 [==============================] - 115s 210ms/step - loss: 0.1214 - accuracy: 0.9518 - val_loss: 0.3050 - val_accuracy: 0.8904
# Epoch 18/20
# 548/548 [==============================] - 111s 203ms/step - loss: 0.1145 - accuracy: 0.9548 - val_loss: 0.2367 - val_accuracy: 0.9162
# Epoch 19/20
# 548/548 [==============================] - 115s 210ms/step - loss: 0.1062 - accuracy: 0.9592 - val_loss: 0.2314 - val_accuracy: 0.9245
# Epoch 20/20
# 548/548 [==============================] - 114s 208ms/step - loss: 0.1081 - accuracy: 0.9578 - val_loss: 0.2533 - val_accuracy: 0.9109

# %%
# model3.save('cat_dog_detector.h5')

# %%
summary = pd.DataFrame(model3.history.history)

# %%
summary[["loss", "val_loss"]].plot()
plt.show()

# %%
summary[["accuracy", "val_accuracy"]].plot()
plt.show()

# %% [markdown]
# # Evaluation on Validation Data

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
score = model3.evaluate(val_image_gen)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 72/72 [==============================] - 6s 86ms/step - loss: 0.2533 - accuracy: 0.9109
# Test loss: 0.25327298045158386
# Test accuracy: 0.9109170436859131

# %%
pred_prob = model3.predict(val_image_gen)
pred_prob
# Out:
# 72/72 [==============================] - 6s 83ms/step
# array([[0.00259651],
#        [0.7869491 ],
#        [0.00414687],
#        ...,
#        [0.98613703],
#        [0.9999925 ],
#        [0.99473614]], dtype=float32)

# %%
y_pred = pred_prob > 0.5
y_pred
# Out:
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
y_test = val_image_gen.classes

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      1219
#            1       0.87      0.95      0.91      1071
#
#     accuracy                           0.91      2290
#    macro avg       0.91      0.91      0.91      2290
# weighted avg       0.91      0.91      0.91      2290

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1073,  146],
#        [  58, 1013]])

# %%
model3.save('cat_dog_detector.h5')

# %% [markdown]
# # Prediction-1

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model = load_model('cat_dog_detector.h5')

# %%
img_path = "./data/test/10071.jpg"

# %%
img = image.load_img(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=334x500 at 0x7F0E1A404D60>

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (500, 334, 3)

# %%
resized_img = image.smart_resize(img, (128, 128))  # img has to be numpy array
resized_img.shape

# resized_img = img.resize((128, 128)) # img has to be image format (like jpg, png etc)
# resized_img
# Out:
# (128, 128, 3)

# %%
resized_img.max()
# Out:
# 226.57806

# %%
resized_img = resized_img / 255

# %%
plt.imshow(resized_img)
plt.show()

# %%
resized_img = np.expand_dims(resized_img, axis=0)
resized_img.shape
# Out:
# (1, 128, 128, 3)

# %%
model.predict(resized_img)
# Out:
# 1/1 [==============================] - 0s 343ms/step
# array([[2.555779e-10]], dtype=float32)

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# # Prediction-2

# %%
random_image = random.sample(os.listdir(test_path), 1)
random_image
# Out:
# ['5528.jpg']

# %%
image_path = os.path.join(test_path, random_image[0])
image_path
# Out:
# 'data/test/5528.jpg'

# %%
my_image = image.load_img(image_path, target_size=image_shape)

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F0E1A354F10>

# %%
type(my_image)
# Out:
# PIL.Image.Image

# %%
# my_image = np.array(my_image)
my_image = image.img_to_array(my_image)

# %%
my_image.max()
# Out:
# 255.0

# %%
my_image = my_image / 255

# %%
my_image.shape
# Out:
# (128, 128, 3)

# %%
my_image = np.expand_dims(my_image, axis=0)

# %%
my_image.shape
# Out:
# (1, 128, 128, 3)

# %%
model.predict(my_image)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[0.9845428]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
def pred_and_plot(model, img_size):
    """
    Imports an image located at filename, makes a prediction on it with
    a trained model and plots the image with the predicted class as the title.
    """
    # Import the target image and preprocess it
    random_image = random.sample(os.listdir(test_path), 1)
    img_path = os.path.join(test_path, random_image[0])
    img = image.load_img(img_path, target_size=img_size)
    img = np.array(img)
    if img.max() > 1:
        img = img/255

    # Make a prediction
    pred = model.predict(np.expand_dims(img, axis=0))
    print("prediction_probability: ", pred.max())

    # Get the predicted class
    if len(pred[0]) > 1:  # check for multi-class
        pred_class = class_names[pred.argmax()]
        # if more than one output, take the max
    else:
        pred_class = class_names[int(tf.round(pred)[0][0])]
        # if only one output, round

    # Plot the image and predicted class
    plt.imshow(img)
    plt.title(f"Prediction: {pred_class}")
    plt.axis(False);

# %%
pred_and_plot(model, image_shape[:2])
# Out:
# 1/1 [==============================] - 0s 16ms/step
# prediction_probability:  0.01981122

# %% [markdown]
# ![Hilmi Katirci Data Analyst.png](data:image/png;base64,...)
